# %% [markdown]
# <a href="https://colab.research.google.com/github/ayaandroid/summer-of-code-2024/blob/main/DSoC_AIML_Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
# !mkdir ~/.kaggle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/hallelujah/kaggle.json ~/.kaggle/kaggle.json

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download mlg-ulb/creditcardfraud
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud
# License(s): DbCL-1.0
# ...
#  88% 58.0M/66.0M [00:00<00:00, 214MB/s]
# 100% 66.0M/66.0M [00:00<00:00, 210MB/s]

# %%
# !unzip creditcardfraud.zip
# Out:
# Archive:  creditcardfraud.zip
#   inflating: creditcard.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
with open('creditcard.csv') as file:
  df = pd.read_csv(file)
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
df.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1081

# %%
df.drop_duplicates()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# ...

# %%
df['Class'].sum()
# Out:
# 492

# %%
features = [col for col in df.columns if col != 'Class']
X = df[features].to_numpy()
X = (X-X.mean())/X.std()
y = df['Class'].to_numpy()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 42)
X_res, y_res = sm.fit_resample(X_train, y_train)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_res, y_res)
y_pred = model.predict(X_test)
from sklearn.metrics import confusion_matrix, classification_report
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[40237 30828]
#  [   47    90]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.57      0.72     71065
#            1       0.00      0.66      0.01       137
#
#     accuracy                           0.57     71202
#    macro avg       0.50      0.61      0.36     71202
# weighted avg       1.00      0.57      0.72     71202

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_res, y_res)
y_pred = rf.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[71051    14]
#  [   26   111]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71065
#            1       0.89      0.81      0.85       137
#
#     accuracy                           1.00     71202
#    macro avg       0.94      0.91      0.92     71202
# weighted avg       1.00      1.00      1.00     71202

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier()
xgb.fit(X_res, y_res)
y_pred = xgb.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[71047    18]
#  [   26   111]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71065
#            1       0.86      0.81      0.83       137
#
#     accuracy                           1.00     71202
#    macro avg       0.93      0.90      0.92     71202
# weighted avg       1.00      1.00      1.00     71202

# %%
from lightgbm import LGBMClassifier
lgbm = LGBMClassifier()
lgbm.fit(X_res, y_res)
y_pred = lgbm.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [LightGBM] [Info] Number of positive: 213250, number of negative: 213250
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.127306 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7650
# [LightGBM] [Info] Number of data points in the train set: 426500, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [[71036    29]
#  [   23   114]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71065
#            1       0.80      0.83      0.81       137
#
#     accuracy                           1.00     71202
#    macro avg       0.90      0.92      0.91     71202
# weighted avg       1.00      1.00      1.00     71202
